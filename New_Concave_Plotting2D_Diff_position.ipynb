# %%
import scipy
import numpy
import matplotlib as mpl
import numpy as np
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')
from matplotlib.colors import LogNorm
from __future__ import division

# %%
exp1 = np.fromfile('/home/sergey/Documents/Raw/NewConcave/Top Gate/Topgate-vs-Lens(FULL)_QPC1@-1365mV_QPC2(emitter)@-1300mV_SD=-1mV Detector Current_Matrix.txt',dtype=float,count=-1, sep=" ")
exp2 = np.fromfile('/home/sergey/Documents/Raw/NewConcave/Top Gate/Topgate-vs-Lens_QPC1(emitter)@-1365mV_QPC2@-1300mV_SD=-1mV Detector Current_Matrix.txt',dtype=float,count=-1, sep=" ")
exp3 = np.fromfile('/home/sergey/Documents/Raw/NewConcave/Magnetic Field/B-vs-QPC2(Emitter)_QPC1@7th_SD=-0.7mV Detector Current_Matrix.txt',dtype=float,count=-1, sep=" ")
exp4 = np.fromfile('/home/sergey/Documents/Raw/NewConcave/Lens/Lens-vs-Detector(QPC1)_QPC2@3rd_sd=-0.3mV Detector Current_Matrix.txt',dtype=float,count=-1, sep=" ")
exp5 = np.fromfile('/home/sergey/Documents/Raw/NewConcave/Lens/Lens-vs-Emitter(QPC2)_QPC1@7th_SD=-1mV Detector Current_Matrix.txt',dtype=float,count=-1, sep=" ")

# %%
exp5.shape
# Out:
# (12221,)

# %%
exp1 = np.reshape(exp1, (301,-1))
exp2 = np.reshape(exp2, (301,-1))
exp3 = np.reshape(exp3, (101,-1))
exp4 = np.reshape(exp4, (110,-1))
exp5 = np.reshape(exp5, (121,-1))

# %%
exp1.shape
# Out:
# (301, 301)

# %%
row_sums = exp1.sum(axis=1)
exp1_norm = exp1 / row_sums[:, numpy.newaxis]

# %%
row_sums = exp2.sum(axis=1)
exp2_norm = exp2 / row_sums[:, numpy.newaxis]

# %%
exp2_norm
# Out:
# array([[ 0.00803003,  0.00826551,  0.00845559, ...,  0.0077209 ,
#          0.00775955,  0.00768846],
#        [ 0.00795893,  0.00814129,  0.00834809, ...,  0.00776362,
#          0.00774961,  0.00766984],
#        [ 0.00793613,  0.00814228,  0.00835022, ...,  0.00782312,
#          0.00782259,  0.00775996],
#        ...,
#        [ 0.00749948,  0.00779518,  0.00803619, ...,  0.00747189,
#          0.00749515,  0.00751643],
#        [ 0.007411  ,  0.00764337,  0.00784155, ...,  0.0077506 ,
#          0.00775077,  0.00757441],
#        [ 0.00732624,  0.00755741,  0.00773179, ...,  0.0079429 ,
#          0.00800463,  0.00792648]])

# %%
exp1g=np.gradient(exp1)
exp2g=np.gradient(exp2)
exp1gn=np.gradient(exp1_norm)
exp2gn=np.gradient(exp2_norm)
exp3g=np.gradient(exp3)
exp4g=np.gradient(exp4)
exp5g=np.gradient(exp5)

# %%
from matplotlib.colors import LogNorm
#norm=LogNorm(vmin=0.1, vmax=20)
p=plt.imshow(exp1_norm, interpolation='none', aspect='auto',extent=[-1.5,0,-3,0])
plt.colorbar(label='$I_{NORM}$ (a.u.)')

#plt.ylim(-2,0)
#plt.xlim(-2,-1)
plt.ylabel("$V_T$ (V)")
plt.xlabel("$V_L$ (V)")
plt.title('Topgate') 

#plt.contour(bf1,20,  extent=[12,-20,-2,0.7], )
plt.savefig('/home/sergey/Documents/nc1', format='pdf')

# %%
from matplotlib.colors import LogNorm
#norm=LogNorm(vmin=0.1, vmax=20)
p=plt.imshow(exp2_norm, interpolation='none', aspect='auto',extent=[-0.95,-0.45,-3,0])
plt.colorbar(label='$I_{NORM}$ (a.u.)')

#plt.ylim(-2,0)
#plt.xlim(-2,-1)
plt.ylabel("$V_T$ (V)")
plt.xlabel("$V_L$ (V)")
plt.title('Topgate') 

#plt.contour(bf1,20,  extent=[12,-20,-2,0.7], )
plt.savefig('/home/sergey/Documents/nc2', format='pdf')

# %%
from matplotlib.colors import LogNorm
#norm=LogNorm(vmin=0.1, vmax=20)
p=plt.imshow(exp3, interpolation='none', aspect='auto',extent=[-0.95,-0.45,-3,0])
plt.colorbar(label='$I_{NORM}$ (a.u.)')

#plt.ylim(-2,0)
#plt.xlim(-2,-1)
plt.ylabel("$V_T$ (V)")
plt.xlabel("$V_L$ (V)")
plt.title('Topgate') 

#plt.contour(bf1,20,  extent=[12,-20,-2,0.7], )
#plt.savefig('/home/sergey/Documents/nc2', format='pdf')

# %%
exp5.shape
# Out:
# (121, 101)

# %%
p=plt.imshow(exp5g[1]*1E9,interpolation='none',aspect='auto', extent=[-100,100,0.5,-2],vmax=0.5,vmin=-0.2)

plt.colorbar(label='Conductance ($e^2/h$)')
#plt.ylim(-0.9,-2)
#plt.xlim(-60,60)
plt.ylabel("$V_L$ (V)")
plt.xlabel("B (T)")
plt.title('Concave lense at 2nd plateau') 
#plt.contour(bf1,20,  extent=[12,-20,-2,0.7], )
plt.savefig('/home/sergey/Documents/bf2', format='pdf')

# %%
from matplotlib.colors import LogNorm
#, norm=LogNorm(vmin=0.1, vmax=1) 
p=plt.imshow((exp4g[1])*1E9,interpolation='none', aspect='auto', extent=[-4,0,-1.050,-2.140],vmax=5,vmin=-5)

plt.colorbar(label='$dI/dV_L$ (a.u.)')
plt.ylim(-2.140,-1.050)
plt.xlim(-1.5,0)
plt.ylabel("$V_D$ (V)")
plt.xlabel("$V_L$ (V)")
#plt.title() 
#plt.contour(bf1,20,  extent=[12,-20,-2,0.7], )
plt.savefig('/home/sergey/Documents/bf3', format='pdf')

# %%
from matplotlib.colors import LogNorm
#, norm=LogNorm(vmin=0.1, vmax=1) 
p=plt.imshow((exp5g[1])*1E9,interpolation='none', aspect='auto', extent=[-4,0,-1.050,-2.140],vmax=1,vmin=-1)

plt.colorbar(label='$dI/dV_L$ (a.u.)')
plt.ylim(-2.140,-1.050)
plt.xlim(-1.5,0)
plt.ylabel("$V_D$ (V)")
plt.xlabel("$V_L$ (V)")
#plt.title() 
#plt.contour(bf1,20,  extent=[12,-20,-2,0.7], )
plt.savefig('/home/sergey/Documents/bf3', format='pdf')

# %%
sd.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5c79f4070097> in <module>()
# ----> 1 sd.shape
#
# NameError: name 'sd' is not defined

# %%
from matplotlib.colors import LogNorm
#,norm=LogNorm(vmin=0.1, vmax=20)
p=plt.imshow(exp6g2*1E9, interpolation='none', aspect='auto',extent=[-1.8,-0.7,-0.7,-1.8,],vmin=-0, vmax=4)
plt.colorbar(label='I (nA)')
plt.ylim(-1.8,-0.8)
#plt.ylim(-1,-10)
#plt.xlim(-2,-1)
plt.ylabel("$V_{QPC1}$ (mV)")
plt.xlabel("$V_{QPC2}$ (V)")
plt.title('$V_L=-0.7$ V High coupling regime') 

#plt.contour(bf1,20,  extent=[12,-20,-2,0.7], )
plt.savefig('/home/sergey/Documents/hc1', format='pdf')

# %%
from matplotlib.colors import LogNorm
#,norm=LogNorm(vmin=0.1, vmax=20)
p=plt.imshow(exp7g*1E9, interpolation='none', aspect='auto',extent=[-1.8,-0.7,-0.7,-1.8,],vmin=0, vmax=1)
plt.colorbar(label='I (nA)')

plt.ylim(-1.8,-0.8)
#plt.xlim(-2,-1)
plt.ylabel("$V_{QPC1}$ (mV)")
plt.xlabel("$V_{QPC2}$ (V)")
plt.title('$V_L=-1.5$ V Low coupling regime') 

#plt.contour(bf1,20,  extent=[12,-20,-2,0.7], )
plt.savefig('/home/sergey/Documents/lc1', format='pdf')

# %%
exp9.shape
# Out:
# (437, 221)

# %%
import numpy
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Set up grid and test data
nx, ny = 221, 437
x = range(nx)
y = range(ny)

data = exp9*1E11
hf = plt.figure()
ha = hf.add_subplot(111, projection='3d')

X, Y = numpy.meshgrid(x, y)  # `plot_surface` expects `x` and `y` data to be 2D
ha.plot_wireframe(X, Y, data,rstride=10, cstride=10)
ha.set_zlim(0, 50)
#ha.set_xlim(50, 100)
#ha.set_ylim(50, 100)
plt.show()

# %%
from matplotlib.colors import LogNorm
#,norm=LogNorm(vmin=0.1, vmax=20)
p=plt.imshow(exp8g2*1E9, interpolation='none', aspect='auto',extent=[-1.8,-0.7,-0.7,-1.8,],vmin=-0, vmax=4)
plt.colorbar(label='I (nA)')
plt.ylim(-1.8,-0.8)
#plt.ylim(-1,-10)
#plt.xlim(-2,-1)
plt.ylabel("$V_{QPC1}$ (mV)")
plt.xlabel("$V_{QPC2}$ (V)")
plt.title('$V_L=-0.8$ V High coupling regime (minimum)') 

#plt.contour(bf1,20,  extent=[12,-20,-2,0.7], )
plt.savefig('/home/sergey/Documents/hc1', format='pdf')
