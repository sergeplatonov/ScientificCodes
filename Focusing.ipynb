# %%
import numpy as np
import scipy
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
exp1 = np.fromfile("D:\mode1.dat",dtype=float,count=-1, sep=" ")
exp1 = np.reshape(exp1, (-1,3))
exp2 = exp1.transpose()
exp3 = np.fromfile("D:\mode11.dat",dtype=float,count=-1, sep=" ")
exp3 = np.reshape(exp3, (-1,2))
exp4 = exp3.transpose()

# %%
exp4
# Out:
# array([[ -3.97900000e-02,  -3.97900000e-02,  -3.88000000e-02,
#          -3.83100000e-02,  -3.82800000e-02,  -3.72700000e-02,
#          -3.72800000e-02,  -3.67900000e-02,  -3.62900000e-02,
#          -3.57800000e-02,  -3.47900000e-02,  -3.47700000e-02,
#          -3.42800000e-02,  -3.37800000e-02,  -3.32600000e-02,
#          -3.22600000e-02,  -3.22600000e-02,  -3.17800000e-02,
#          -3.12900000e-02,  -3.07800000e-02,  -2.98000000e-02,
#          -2.97700000e-02,  -2.92800000e-02,  -2.87800000e-02,
#          -2.82500000e-02,  -2.78000000e-02,  -2.72500000e-02,
#          -2.67700000e-02,  -2.62800000e-02,  -2.57700000e-02,
#          -2.47600000e-02,  -2.47600000e-02,  -2.42700000e-02,
#          -2.37700000e-02,  -2.32700000e-02,  -2.23100000e-02,
#          -2.22800000e-02,  -2.17900000e-02,  -2.08400000e-02,
#          -2.03700000e-02,  -1.98000000e-02,  -1.93000000e-02,
#          -1.88000000e-02,  -1.83300000e-02,  -1.82900000e-02,
# ...

# %%
plt.plot(exp2[0],exp2[1],'b')

# %%
x = scipy.linspace(-10,10,1000)
f=(np.sinc(0.3*(x-1))+np.sinc(0.6*(x-3.5)))*(np.sinc(0.3*(x-1))+np.sinc(0.6*(x-3.5)))
plt.plot(x,f,'r')
plt.plot(exp2[0]*179,exp2[1]*1E8*1.5,'b')
#plt.xlim(-5,5)

# %%
x = scipy.linspace(-10,10,1000)
f=(np.sinc(0.3*(x-1))+np.sinc(0.6*(x-3))+np.sinc(0.9*(x+1)))*(np.sinc(0.3*(x-1))+np.sinc(0.6*(x-3))+np.sinc(0.9*(x+1)))
plt.plot(x,f,'r')
#plt.plot(exp2[0]*179,exp2[1]*1E8*1.5,'b')
#plt.xlim(-5,5)

# %%
plt.plot(exp4[0]*179,exp4[1]*1E8*1.5,'b')
plt.xlim(-10,10)
plt.ylim(0,0.5)
# Out:
# (0, 0.5)

# %%
x = scipy.linspace(-10,10,1000)
f=(np.sinc(0.3*(x-1)))*(np.sinc(0.3*(x-1)))
plt.plot(x,f)
plt.plot(exp4[0]*179,exp4[1]*1E8*1.5*2,'o')
#plt.xlim(-5,5)

# %%
exp1 = np.fromfile("D:\mode22.dat",dtype=float,count=-1, sep=" ")
exp1 = np.reshape(exp1, (-1,2))
exp2 = exp1.transpose()

# %%
a=0.5
b=1.3
x = scipy.linspace(-10,10,1000)
f=(np.sinc(a*(x-2))+b*np.sinc(a*(x+5)))*(np.sinc(a*(x-2))+b*np.sinc(a*(x+5)))
plt.plot(x,f)
plt.plot(exp2[0]*179,exp2[1]*1E8*1.5*1.2,'o')
#plt.xlim(-5,5)

# %%
exp1 = np.fromfile("D:\mode22.dat",dtype=float,count=-1, sep=" ")
exp1 = np.reshape(exp1, (-1,2))
exp2 = exp1.transpose()
exp3 = np.fromfile("D:\p3.dat",dtype=float,count=-1, sep=" ")
exp3 = np.reshape(exp3, (-1,2))
exp3 = exp3.transpose()
exp0 = np.fromfile("D:\mode11.dat",dtype=float,count=-1, sep=" ")
exp0 = np.reshape(exp0, (-1,2))
exp0 = exp0.transpose()
exp4 = np.fromfile("D:\p4.dat",dtype=float,count=-1, sep=" ")
exp4 = np.reshape(exp4, (-1,2))
exp4 = exp4.transpose()
exp5 = np.fromfile("D:\p5.dat",dtype=float,count=-1, sep=" ")
exp5 = np.reshape(exp5, (-1,2))
exp5 = exp5.transpose()

# %%
x = scipy.linspace(-10,10,1000)
#f=(np.sinc(0.3*(x-4))+np.sinc(0.6*(x+1))+np.sinc(0.9*(x+2)))*(np.sinc(0.3*(x-4))+np.sinc(0.6*(x+1))+np.sinc(0.9*(x+2)))
#plt.plot(x,f)
plt.plot(exp3[0]*179,exp3[1]*1E8*1.5*1.2,'o')
#plt.xlim(-5,5)

# %%
plt.plot(exp2[0],exp2[1],'o')

# %%
def func1(x,a,b,c):
    return c*np.sinc(b*x+a)
def func2(x,d,b,c):
    return c*np.sinc(2*b*x+d)
def func3(x,f,b,c):
    return c*np.sinc(3*b*x+f)
def func4(x,g,b,c):
    return c*np.sinc(4*b*x+g)
def func5(x,h,b,c):
    return c*np.sinc(5*b*x+h)
def func0(x,a,b,c):
    return c*np.sinc(b*x+a)*c*np.sinc(b*x+a)
def funcall(x, a, b, c, d):
    return c*(np.sinc(b*x+a)+np.sinc(2*b*x+d))*(np.sinc(b*x+a)+np.sinc(2*b*x+d))
def funcall3(x, a, b, c, d, f ):
    return c*(np.sinc(b*x+a)+np.sinc(2*b*x+d)+np.sinc(3*b*x+f))*c*(np.sinc(b*x+a)+np.sinc(2*b*x+d)+np.sinc(3*b*x+f))
def funcall4(x, a, b, c, d, f, g ):
    return c*(np.sinc(b*x+a)+np.sinc(2*b*x+d)+np.sinc(3*b*x+f)+np.sinc(4*b*x+g))*c*(np.sinc(b*x+a)+np.sinc(2*b*x+d)+np.sinc(3*b*x+f)+np.sinc(4*b*x+g))
def funcall5(x, a, b, c, d, f, g, h ):
    return c*(np.sinc(b*x+a)+np.sinc(2*b*x+d)+np.sinc(3*b*x+f)+np.sinc(4*b*x+g)+np.sinc(5*b*x+h))*c*(np.sinc(b*x+a)+np.sinc(2*b*x+d)+np.sinc(3*b*x+f)+np.sinc(4*b*x+g)+np.sinc(5*b*x+h))

# %%
#from scipy.optimize import curve_fit
#popt, pcov = curve_fit(func, exp2[0], exp2[1])
from scipy.optimize import curve_fit
popt0, pcov0 = curve_fit(func0, exp0[0]*1000/3, exp0[1]*1E9)
popt, pcov = curve_fit(funcall, exp2[0]*1000/3, exp2[1]*1E9)
#popt3, pcov3 = curve_fit(funcall3, exp3[0]*1000/2.3, exp3[1]*1E9)

# %%
plt.plot(exp0[0]*1000/3,func0(exp0[0]*1000/3,popt0[0],popt0[1],popt0[2]))
plt.plot(exp0[0]*1000/3,func1(exp0[0]*1000/3,popt0[0],popt0[1],popt0[2]))
plt.plot(exp0[0]*1000/3,exp0[1]*1E9,'o')

# %%
print popt0
print popt
print popt3
print popt4
# Out:
# [ 0.01217006  0.36042684  1.61854105]
# [ 0.70133312 -0.17269376  5.25061212 -0.3279115 ]
# [ 0.71676389 -0.10697962  3.20054198 -0.44388482 -2.0434706 ]
# [ 6.388196   -0.1287046   4.61383772  0.97031917 -0.36066818 -1.87548617]

# %%
plt.plot(exp2[0]*1000/3,funcall(exp2[0]*1000/3,popt[0],popt[1],popt[2],popt[3]))
plt.plot(exp2[0]*1000/3,func1(exp2[0]*1000/3,popt[0],popt[1],popt[2]))
plt.plot(exp2[0]*1000/3,func2(exp2[0]*1000/3,popt[3],popt[1],popt[2]))
plt.plot(exp2[0]*1000/3,exp2[1]*1E9,'o')

# %%
c2=2.1
popt3, pcov3 = curve_fit(funcall3, exp3[0]*1000/c2, exp3[1]*1E9)
plt.plot(exp3[0]*1000/c2,funcall3(exp3[0]*1000/c2,popt3[0],popt3[1],popt3[2],popt3[3],popt3[4]))
plt.plot(exp3[0]*1000/c2,func1(exp3[0]*1000/c2,popt3[0],popt3[1],popt3[2]))
plt.plot(exp3[0]*1000/c2,func2(exp3[0]*1000/c2,popt3[3],popt3[1],popt3[2]))
plt.plot(exp3[0]*1000/c2,func3(exp3[0]*1000/c2,popt3[4],popt3[1],popt3[2]))
#f=func1(exp3[0]*1000/c2,popt3[0],popt3[1],popt3[2])+func2(exp3[0]*1000/c2,popt3[3],popt3[1],popt3[2])+func3(exp3[0]*1000/c2,popt3[4],popt3[1],popt3[2])
#plt.plot(exp3[0]*1000/c2,f*f)
plt.plot(exp3[0]*1000/c2,exp3[1]*1E9,'o')

# %%
c3=3.9
popt4, pcov4 = curve_fit(funcall4, exp4[0]*1000/c3, exp4[1]*1E9)
plt.plot(exp4[0]*1000/c3,funcall4(exp4[0]*1000/c3,popt4[0],popt4[1],popt4[2],popt4[3],popt4[4],popt4[5]))
plt.plot(exp4[0]*1000/c3,func1(exp4[0]*1000/c3,popt4[0],popt4[1],popt4[2]))
plt.plot(exp4[0]*1000/c3,func2(exp4[0]*1000/c3,popt4[3],popt4[1],popt4[2]))
plt.plot(exp4[0]*1000/c3,func3(exp4[0]*1000/c3,popt4[4],popt4[1],popt4[2]))
plt.plot(exp4[0]*1000/c3,func4(exp4[0]*1000/c3,popt4[5],popt4[1],popt4[2]))
f=func1(exp3[0]*1000/c2,popt3[0],popt3[1],popt3[2])+func2(exp3[0]*1000/c2,popt3[3],popt3[1],popt3[2])+func3(exp3[0]*1000/c2,popt3[4],popt3[1],popt3[2])
#plt.plot(exp3[0]*1000/c2,f*f)
plt.plot(exp4[0]*1000/c3,exp4[1]*1E9,'o')

# %%
c4=3.9
popt5, pcov5 = curve_fit(funcall5, exp5[0]*1000/c4, exp5[1]*1E9)
plt.plot(exp5[0]*1000/c4,funcall5(exp5[0]*1000/c4,popt4[0],popt4[1],popt4[2],popt4[3],popt4[4],popt4[5], 6))
#plt.plot(exp4[0]*1000/c3,func1(exp4[0]*1000/c3,popt4[0],popt4[1],popt4[2]))
#plt.plot(exp4[0]*1000/c3,func2(exp4[0]*1000/c3,popt4[3],popt4[1],popt4[2]))
#plt.plot(exp4[0]*1000/c3,func3(exp4[0]*1000/c3,popt4[4],popt4[1],popt4[2]))
#plt.plot(exp4[0]*1000/c3,func4(exp4[0]*1000/c3,popt4[5],popt4[1],popt4[2]))
#f=func1(exp3[0]*1000/c2,popt3[0],popt3[1],popt3[2])+func2(exp3[0]*1000/c2,popt3[3],popt3[1],popt3[2])+func3(exp3[0]*1000/c2,popt3[4],popt3[1],popt3[2])
#plt.plot(exp3[0]*1000/c2,f*f)
plt.plot(exp5[0]*1000/c3,exp5[1]*1E9,'o')

# %%
c2=1
def funcall(x, a, b, c, d,f):
    return c*(np.sinc(b*x+a)+f*np.sinc(b*x+d))*c*(np.sinc(b*x+a)+f*np.sinc(b*x+d))
def func1(x,a,b,c):
    return c*np.sinc(b*x+a)
def func2(x,d,b,c,f):
    return c*np.sinc(b*x+d)
popt2, pcov2 = curve_fit(funcall, exp2[0]*1000/c2, exp2[1]*1E9)
print popt2
plt.plot(exp2[0]*1000/c2,funcall(exp2[0]*1000/c2,popt2[0],0.11,3.3,-1.6,0.9))
plt.plot(exp2[0]*1000/c2,func1(exp2[0]*1000/c2,popt2[0],0.11,3.3))
plt.plot(exp2[0]*1000/c2,func2(exp2[0]*1000/c2,-1.6,0.11,3.3,0.9))
plt.plot(exp2[0]*1000/c2,exp2[1]*1E9,'o')
# Out:
# [-0.04357836 -0.07995699  1.18028335 -0.04360478  1.36066961]
