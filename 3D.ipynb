# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
get_ipython().magic(u'matplotlib inline')
# %config InlineBackend.figure_format = 'retina'
from matplotlib import cm
 
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
Z = (X**2-Y**2)
  
data
fig = plt.figure()
ax = fig.gca(projection = '3d')
x2 = np.linspace(-10, -30, 100)
y2 = np.linspace(-10, -10, 100)
z2=1
surf = ax.plot_surface(X, Y, Z,
                      rstride = 3,
                      cstride = 3,
                      cmap = cm.coolwarm,
                      linewidth = 0.5,
                      antialiased = True)
surf2 = ax.plot_surface(x2, y2, z2,
                      rstride = 3,
                      cstride = 3,
                      cmap = cm.coolwarm,
                      linewidth = 0,
                      antialiased = True)
#plt.tick_params(labeltop=False, labelbottom=False, bottom=False, top=False, labelright=False, left=False) 
ax.view_init(elev=20, azim=60)
ax.dist = 12
plt.show()

# %%
x = np.where(x<0)

# %%
x = np.linspace(-20, 20, 100)

# %%
x =
# Out:
#   File "<ipython-input-35-2ec917a9f03c>", line 1
#     x =
#         ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import plotly.plotly as py
from plotly.graph_objs import Surface
import plotly as py
py.tools.set_credentials_file(username='trastetra', api_key='22y8mwol6d')

import plotly.plotly as py
import plotly.tools as plotly_tools
from plotly.graph_objs import *

py.sign_in("trastetra", "22y8mwol6d")

x = np.linspace(-30, 30, 100)
y = np.linspace(-30, 30, 100)
X, Y = np.meshgrid(x, y)

z1 = (X**2-Y**2)




layout = go.Layout(
    xaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    ),
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    ))

py.iplot([
    dict(z=z1, showscale=False, type='surface',colorscale='Greys')],
    filename='multiple-surfaces')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~trastetra/3.embed" height="525px" width="100%"></iframe>
